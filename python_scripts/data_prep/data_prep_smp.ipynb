# %% [markdown]
# ### **<h1>Data SMP</h1>**

# %%
# Imports
import pandas as pd
import plotly.graph_objects as go

# Permission to access my Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FILE_PATH = "/content/drive/MyDrive/Doral_Energy/data/raw_data/smp.xlsx"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the data

# %%
df = pd.read_excel(FILE_PATH)
df
# Out:
#             תאריך       שעה  עלות שולית מערכתית כולל אילוצים  \
# 0      2021/01/01  00:00:00                           117.24
# 1      2021/01/01  00:30:00                           114.10
# 2      2021/01/01  01:00:00                           111.19
# 3      2021/01/01  01:30:00                           100.81
# 4      2021/01/01  02:00:00                           110.02
# ...           ...       ...                              ...
# 33593  30/11/2022  21:30:00                           102.44
# 33594  30/11/2022  22:00:00                           102.45
# 33595  30/11/2022  22:30:00                           102.45
# 33596  30/11/2022  23:00:00                           102.45
# 33597  30/11/2022  23:30:00                           102.44
#
#        עלות שולית מערכתית ללא אילוצים
# 0                              113.80
# 1                              112.70
# 2                              111.19
# 3                              100.81
# 4                              110.02
# ...                               ...
# 33593                          129.85
# 33594                          175.90
# 33595                          122.00
# 33596                          112.77
# 33597                          105.19
#
# [33598 rows x 4 columns]

# %% [markdown]
# # Change column names from Hebrew to English

# %%
df.rename(columns={'תאריך': 'date', 'שעה': 'hour', 'עלות שולית מערכתית כולל אילוצים': 'smp_const', 'עלות שולית מערכתית ללא אילוצים': 'smp_no_const' }, inplace=True)
df.head()
# Out:
#          date      hour  smp_const  smp_no_const
# 0  2021/01/01  00:00:00     117.24        113.80
# 1  2021/01/01  00:30:00     114.10        112.70
# 2  2021/01/01  01:00:00     111.19        111.19
# 3  2021/01/01  01:30:00     100.81        100.81
# 4  2021/01/01  02:00:00     110.02        110.02

# %% [markdown]
# # Check the types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33598 entries, 0 to 33597
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          33598 non-null  object
#  1   hour          33598 non-null  object
#  2   smp_const     33598 non-null  float64
#  3   smp_no_const  33598 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# #Get some understanding about the range of SMP

# %%
df.describe()
# Out:
#           smp_const  smp_no_const
# count  33598.000000  33598.000000
# mean     118.587472    121.580089
# std       38.976578     23.257673
# min       22.000000     71.430000
# 25%      101.570000    105.300000
# 50%      108.730000    112.760000
# 75%      121.500000    129.025000
# max     1421.990000    220.000000

# %% [markdown]
# # Check if there are missing values

# %%
df.isna().any(axis=1).sum()
# Out:
# 0

# %% [markdown]
# # Are there any duplicates?

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df[df.duplicated()]
# Out:
#              date      hour  smp_const  smp_no_const
# 16750  2021/12/17  00:00:00     104.68        106.73
# 16751  2021/12/17  00:30:00     106.73        107.70
# 16752  2021/12/17  01:00:00     105.41        107.17
# 16753  2021/12/17  01:30:00      97.18        103.81
# 16754  2021/12/17  02:00:00      95.18        100.04
# ...           ...       ...        ...           ...
# 16987  2021/12/19  22:30:00     109.12        109.91
# 16988  2021/12/19  23:00:00     109.13        106.45
# 16989  2021/12/19  23:30:00     104.99        100.11
# 32063  30/10/2022  01:00:00     109.84        107.67
# 32065  30/10/2022  01:30:00     100.35        106.24
#
# [146 rows x 4 columns]

# %%
# Drop the rows
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True, drop=True)
df
# Out:
#              date      hour  smp_const  smp_no_const
# 0      2021/01/01  00:00:00     117.24        113.80
# 1      2021/01/01  00:30:00     114.10        112.70
# 2      2021/01/01  01:00:00     111.19        111.19
# 3      2021/01/01  01:30:00     100.81        100.81
# 4      2021/01/01  02:00:00     110.02        110.02
# ...           ...       ...        ...           ...
# 33447  30/11/2022  21:30:00     102.44        129.85
# 33448  30/11/2022  22:00:00     102.45        175.90
# 33449  30/11/2022  22:30:00     102.45        122.00
# 33450  30/11/2022  23:00:00     102.45        112.77
# 33451  30/11/2022  23:30:00     102.44        105.19
#
# [33452 rows x 4 columns]

# %%
# Get the names of the columns from index 2
column_names = list(df.columns.values[2:])
# Group the data by date and hour
grouped_df = df.groupby(['date', 'hour'])

mask = grouped_df[column_names].transform('nunique') > 1
filtered_df = df.loc[mask.any(axis=1)]

filtered_df
# Out:
# Empty DataFrame
# Columns: [date, hour, smp_const, smp_no_const]
# Index: []

# %% [markdown]
# No different values for the same date and hour

# %% [markdown]
# #Outliers Detection

# %%
fig = go.Figure()
fig.add_trace(go.Box(name='SMP With Constraints', y=df['smp_const'], boxmean='sd'))

fig.update_traces(
    marker=dict(
        color='rgb(8,81,156)',
        outliercolor='rgba(219, 64, 82, 0.6)',
        line=dict(
            outliercolor='rgba(219, 64, 82, 0.6)',
            outlierwidth=2)),
    line_color='rgb(8,81,156)'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="930d5cbd-3240-4414-a95e-8f7f875ffb75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("930d5cbd-3240-4414-a95e-8f7f875ffb75")) {                    Plotly.newPlot(                        "930d5cbd-3240-4414-a95e-8f7f875ffb75",                        [{"boxmean":"sd","name":"SMP With Constraints","y":[117.24,114.1,111.19,100.81,110.02,105.97,105.67,105.41,107.21,110.02,108.97,112.02,112.08,117.02,117.02,117.02,114.54,112.75,112.07,107.0,110.76,110.71,108.04,109.64,110.8,111.41,110.94,112.58,115.02,114.91,121.22,117.33,125.02,114.86,126.41,164.78,149.08,114.01,126.41,114.42,126.4,159.9,159.9,135.0,125.02,118.94,113.88,111.7,111.79,105.0,105.0,109.77,106.58,103.45,102.65,101.82,106.17,106.74,109.85,106.9,109.89,106.81,110.38,112.13,112.8,112.76,112.9,110.97,111.02,106.48,106.3,106.13,105.66,105.05,102.36,101.69,109.89,106.79,110.2,110.2,125.02,126.41,146.4,159.9,165.02,165.02,159.9,165.02,165.02,114.71,160.0,112.43,113.35,112.02,105.0,117.72,113.95,105.0,110.02,103.85,107.82,105.9,105.3,104.52,105.75,109.35,108.76,109.69,109.18,114.18,112.5,114.66,116.68,117.02,115.02,111.97,110.53,107.79,109.04,108.87,109.88,108.0,112.74,113.02,111.45,112.54,111.12,107.81,114.68,125.02,159.9,164.63,163.62,165.02,165.02,164.31,158.45,141.4,121.92,125.02,125.02,105.0,109.0,105.0,107.94,104.06,107.94,107.93,107.76,107.8,107.51,107.22,107.87,107.69,101.87,100.03,103.64,108.18,104.57,106.13,96.97,109.74,108.91,105.61,104.46,104.13,104.13,103.21,103.72,104.03,106.71,108.73,108.66,110.56,108.35
57,113.76,110.36,108.61,110.04,111.29,108.78,108.96,110.53,109.28,109.29,107.73,105.99,107.28,104.56,106.02,107.76,101.24,101.45,105.61,107.88,106.86,109.45,107.15,109.46,108.36,109.88,110.17,109.19,104.57,105.22,107.57,106.86,105.97,99.51,107.16,106.68,107.55,108.95,110.03,107.74,109.43,105.49,108.6,113.77,123.4,113.57,137.7,137.7,137.7,137.7,137.7,123.4,111.81,114.78,119.0,117.7,116.27,110.53,106.1,108.94,109.11,108.26,100.07,106.35,107.44,107.19,106.87,106.18,106.95,109.26,108.93,109.26,111.45,109.8,111.59,111.62,109.22,106.25,105.81,103.8,103.58,103.71,104.38,105.43,104.12,104.65,105.46,106.28,109.18,113.22,110.21,109.15,112.9,136.9,140.03,140.03,140.03,140.03,136.9,135.0,140.03,113.11,108.8,111.6,112.7,111.82,108.34,110.4,106.23,105.45,102.88,100.37,97.21,98.36,99.34,103.48,104.29,107.95,107.91,105.52,108.37,105.17,108.29,110.86,113.0,109.45,105 ...

# %%
def get_outliers(df, series):
  q1 = series.quantile(0.25)
  q3 = series.quantile(0.75)

  if q1*q3 == 0:
    iqr = abs(2*(q1+q3))
    toprange = iqr
    botrange = -toprange
  else:
    iqr = q3-q1
    toprange = q3 + iqr * 1.5
    botrange = q1 - iqr * 1.5

  outliers_top=df[series > toprange]
  outliers_bot= df[series < botrange]
  outliers = pd.concat([outliers_bot, outliers_top], axis=0)

  return (botrange, toprange, outliers)

# %%
botrange, toprange, outliers = get_outliers(df, df['smp_no_const'])
print(toprange)
print(botrange)

outliers
# Out:
# 165.0375
# 69.45750000000001
#              date      hour  smp_const  smp_no_const
# 227    2021/01/05  17:30:00     153.36        169.62
# 229    2021/01/05  18:30:00     153.36        170.15
# 706    2021/01/15  17:00:00     165.14        165.14
# 707    2021/01/15  17:30:00     165.14        165.14
# 857    2021/01/18  20:30:00     165.14        165.14
# ...           ...       ...        ...           ...
# 33443  30/11/2022  19:30:00     111.90        180.71
# 33444  30/11/2022  20:00:00     111.90        182.20
# 33445  30/11/2022  20:30:00     100.61        180.11
# 33446  30/11/2022  21:00:00     102.44        179.03
# 33448  30/11/2022  22:00:00     102.45        175.90
#
# [3047 rows x 4 columns]

# %%
# Change hour and date types 
df['date'] = df['date'].astype('datetime64[ns]').dt.strftime('%d/%m/%Y')
df['hour'] = df['hour'].astype('datetime64[ns]').dt.strftime('%H:%M')

# %%
df
# Out:
#              date   hour  smp_const  smp_no_const
# 0      01/01/2021  00:00     117.24        113.80
# 1      01/01/2021  00:30     114.10        112.70
# 2      01/01/2021  01:00     111.19        111.19
# 3      01/01/2021  01:30     100.81        100.81
# 4      01/01/2021  02:00     110.02        110.02
# ...           ...    ...        ...           ...
# 33447  30/11/2022  21:30     102.44        129.85
# 33448  30/11/2022  22:00     102.45        175.90
# 33449  30/11/2022  22:30     102.45        122.00
# 33450  30/11/2022  23:00     102.45        112.77
# 33451  30/11/2022  23:30     102.44        105.19
#
# [33452 rows x 4 columns]

# %% [markdown]
# # Save the changes to excel file

# %%
df.to_csv('data_smp.csv', index=False)
