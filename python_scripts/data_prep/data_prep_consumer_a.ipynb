# %% [markdown]
# ### **<h1>Data Consumer A - (נתוני צריכה צרכן א)</h1>**

# %%
# Imports
import pandas as pd
import plotly.graph_objects as go
# Permission to access my Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FILE_PATH = "/content/drive/MyDrive/Doral_Energy/data/raw_data/נתוני צריכה צרכן א.xlsx"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the data

# %%
df = pd.read_excel(FILE_PATH)
df
# Out:
#           מתאריך       שעה  כמות kWh
# 0     2021-12-01  00:00:00      1287
# 1     2021-12-01  00:30:00      1217
# 2     2021-12-01  01:00:00      1216
# 3     2021-12-01  01:30:00      1212
# 4     2021-12-01  02:00:00      1206
# ...          ...       ...       ...
# 17515 2022-11-30  21:30:00      1578
# 17516 2022-11-30  22:00:00      1590
# 17517 2022-11-30  22:30:00      1586
# 17518 2022-11-30  23:00:00      1583
# 17519 2022-11-30  23:30:00      1525
#
# [17520 rows x 3 columns]

# %% [markdown]
# # Change column names from Hebrew to English

# %%
df.rename(columns={'מתאריך': 'date', 'שעה': 'hour', 'כמות kWh': 'kWh_amount'}, inplace=True)
df.head()
# Out:
#         date      hour  kWh_amount
# 0 2021-12-01  00:00:00        1287
# 1 2021-12-01  00:30:00        1217
# 2 2021-12-01  01:00:00        1216
# 3 2021-12-01  01:30:00        1212
# 4 2021-12-01  02:00:00        1206

# %% [markdown]
# # Check the types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17520 entries, 0 to 17519
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        17520 non-null  datetime64[ns]
#  1   hour        17520 non-null  object
#  2   kWh_amount  17520 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 410.8+ KB

# %% [markdown]
# # Convert date format and convert kwh_amount from int to float

# %%
df['date'] = df['date'].dt.strftime('%d/%m/%Y')
df['kWh_amount'] = df['kWh_amount'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17520 entries, 0 to 17519
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        17520 non-null  object
#  1   hour        17520 non-null  object
#  2   kWh_amount  17520 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 410.8+ KB

# %% [markdown]
# #Get some understanding about the range of Kwh

# %%
df.describe()
# Out:
#          kWh_amount
# count  17520.000000
# mean     580.859760
# std      592.522665
# min        0.000000
# 25%       47.000000
# 50%      103.000000
# 75%     1208.000000
# max     1627.000000

# %% [markdown]
# # Check if there are missing values

# %%
df.isna().any(axis=1).sum()
# Out:
# 0

# %% [markdown]
# # Are there any duplicates?

# %%
df.duplicated().sum()
# Out:
# 1

# %%
# Display the duplicate row
df[df.duplicated()]
# Out:
#              date      hour  kWh_amount
# 15987  30/10/2022  01:30:00      1329.0

# %% [markdown]
# Just to make sure I looked at the excel and those rows are similar!
# Therefore I will drop one of them

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
# Drop this row
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#              date      hour  kWh_amount
# 0      01/12/2021  00:00:00      1287.0
# 1      01/12/2021  00:30:00      1217.0
# 2      01/12/2021  01:00:00      1216.0
# 3      01/12/2021  01:30:00      1212.0
# 4      01/12/2021  02:00:00      1206.0
# ...           ...       ...         ...
# 17514  30/11/2022  21:30:00      1578.0
# 17515  30/11/2022  22:00:00      1590.0
# 17516  30/11/2022  22:30:00      1586.0
# 17517  30/11/2022  23:00:00      1583.0
# 17518  30/11/2022  23:30:00      1525.0
#
# [17519 rows x 3 columns]

# %%
# group by date and hour, and check if there are rows with different kmh amount values
grouped_df = df.groupby([df['date'], df['hour']])
has_diff_kwh = grouped_df['kWh_amount'].nunique() > 1

grouped_df = df.groupby([df['date'], df['hour']]).filter(lambda x: has_diff_kwh[x.name])
grouped_df
# Out:
#              date      hour  kWh_amount
# 15984  30/10/2022  01:00:00      1509.0
# 15986  30/10/2022  01:00:00      1329.0

# %% [markdown]
# It seems that there was a mistake in the data collection process and 2 different values has been written for the exact date and same hour

# %%
# calculate the average kwh amount
mean_kWh = grouped_df.kWh_amount.mean()
# save it in one of the rows
df.at[15984, 'kWh_amount'] = mean_kWh
# drop one of them, and reset the index
df.drop(index=15986, inplace=True)
df.reset_index(inplace=True, drop=True)
df
# Out:
#              date      hour  kWh_amount
# 0      01/12/2021  00:00:00      1287.0
# 1      01/12/2021  00:30:00      1217.0
# 2      01/12/2021  01:00:00      1216.0
# 3      01/12/2021  01:30:00      1212.0
# 4      01/12/2021  02:00:00      1206.0
# ...           ...       ...         ...
# 17513  30/11/2022  21:30:00      1578.0
# 17514  30/11/2022  22:00:00      1590.0
# 17515  30/11/2022  22:30:00      1586.0
# 17516  30/11/2022  23:00:00      1583.0
# 17517  30/11/2022  23:30:00      1525.0
#
# [17518 rows x 3 columns]

# %% [markdown]
# #Outliers Detection

# %%
fig = go.Figure()
fig.add_trace(go.Box(name='kWh amount', y=df.kWh_amount, boxmean='sd'))

fig.update_traces(
    marker=dict(
        color='rgb(8,81,156)',
        outliercolor='rgba(219, 64, 82, 0.6)',
        line=dict(
            outliercolor='rgba(219, 64, 82, 0.6)',
            outlierwidth=2)),
    line_color='rgb(8,81,156)'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d42e3f5a-5e9b-45fb-b20f-364f9ac4e001" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d42e3f5a-5e9b-45fb-b20f-364f9ac4e001")) {                    Plotly.newPlot(                        "d42e3f5a-5e9b-45fb-b20f-364f9ac4e001",                        [{"boxmean":"sd","name":"kWh amount","y":[1287.0,1217.0,1216.0,1212.0,1206.0,1212.0,1214.0,1216.0,1218.0,1214.0,1216.0,1222.0,1224.0,1218.0,1218.0,1245.0,1280.0,1230.0,1246.0,1274.0,1248.0,1249.0,1193.0,1196.0,1193.0,1183.0,1192.0,1194.0,1200.0,1201.0,1193.0,1257.0,1269.0,1218.0,1235.0,1287.0,1266.0,1285.0,1270.0,1239.0,1094.0,801.0,915.0,1203.0,1139.0,144.0,478.0,1006.0,826.0,1050.0,782.0,461.0,45.0,42.0,42.0,42.0,41.0,42.0,42.0,43.0,46.0,473.0,958.0,1133.0,1035.0,1178.0,1265.0,1269.0,741.0,1024.0,947.0,1100.0,1174.0,1220.0,1261.0,1259.0,1198.0,1192.0,1188.0,1199.0,1266.0,1253.0,1211.0,1211.0,1207.0,1212.0,1252.0,1286.0,1284.0,1264.0,1275.0,1233.0,1278.0,1237.0,1282.0,1298.0,1297.0,1253.0,1234.0,1227.0,1226.0,1230.0,1235.0,1236.0,1235.0,1234.0,1013.0,783.0,269.0,33.0,33.0,34.0,34.0,32.0,32.0,31.0,32.0,31.0,34.0,32.0,32.0,34.0,37.0,35.0,35.0,35.0,34.0,33.0,33.0,41.0,42.0,43.0,42.0,41.0,41.0,41.0,43.0,41.0,42.0,42.0,41.0,42.0,42.0,42.0,42.0,43.0,42.0,42.0,42.0,42.0,42.0,43.0,42.0,42.0,42.0,43.0,42.0,31.0,32.0,29.0,29.0,29.0,30.0,29.0,29.0,31.0,29.0,30.0,30.0,31.0,31.0,31.0,30.0,31.0,32.0,32.0,30.0,39.0,43.0,41.0,42.0,43.0,646.0,1064.0,1264.0,1239.0,1247.0,1300.0,1271.0,1214.0,1255.0,1299.0,1257.0,1302.0,1291.0,1294.0,1270.0,1226.0,1226.0,1215.0,1215.0,1223.0,1223.0,1226.0,1218.0,1216.0,1